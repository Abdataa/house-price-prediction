# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path="data/train.csv"# path to dataset
df=pd.read_csv(path)#reading dataset and storing its tabular
df.head()#diplay some top data
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.hist(bins=50,figsize=(25,20));# visualizing the data

# %%
plt.bar(df['GarageArea'],df['SalePrice']);
plt.xlabel("MSSubClass")
plt.ylabel("SalePrice")
plt.title("MSSubClass Vs SalePrice")
plt.show()

# %%
#splitting data into numeric and object to make simple its analysis and undestand
df_numeric=df.select_dtypes(exclude="object")

# %%
df_numeric.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
age=((df_numeric['YrSold']-df_numeric['YearBuilt']))#age creating  feature extraction
plt.hist(age,bins=(55)) 
plt.xlabel("Age of the house")
plt.ylabel("Frequence of the houses");
plt.title("Distribution of the house by age ")
plt.show()# plotting age

# %%
df_numeric['YearBuilt'].corr(df_numeric['SalePrice'])
# Out:
# np.float64(0.5228973328794969)

# %%
plt.scatter(age,df_numeric['SalePrice'])

# %%
df_numeric['SalePrice'].hist(bins=55);

# %%
sns.heatmap(df_numeric.corr())
# Out:
# <Axes: >

# %%
len(df_numeric.columns)
df_numeric_prt1=df_numeric.iloc[:,0:19]
df_numeric_prt2=df_numeric.iloc[:,19:]
df_numeric_prt1['SalePrice']=df_numeric['SalePrice'] # adding saleprice column for analysis- 
                                                      #purpose
df_numeric_prt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1460 non-null   int64
#  1   MSSubClass    1460 non-null   int64
#  2   LotFrontage   1201 non-null   float64
#  3   LotArea       1460 non-null   int64
#  4   OverallQual   1460 non-null   int64
#  5   OverallCond   1460 non-null   int64
#  6   YearBuilt     1460 non-null   int64
#  7   YearRemodAdd  1460 non-null   int64
#  8   MasVnrArea    1452 non-null   float64
#  9   BsmtFinSF1    1460 non-null   int64
#  10  BsmtFinSF2    1460 non-null   int64
#  11  BsmtUnfSF     1460 non-null   int64
#  12  TotalBsmtSF   1460 non-null   int64
#  13  1stFlrSF      1460 non-null   int64
#  14  2ndFlrSF      1460 non-null   int64
#  15  LowQualFinSF  1460 non-null   int64
#  16  GrLivArea     1460 non-null   int64
#  17  BsmtFullBath  1460 non-null   int64
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error,mean_squared_error
from sklearn.compose import ColumnTransformer

# %%
target='SalePrice'
y_train=df[target]
X_train=df.drop(target
                ,axis=1)

# %%
#feat_eng=['TotalSF']
#X_train.drop(feat_eng,axis=1,inplace=True)

# %%
#featuring engineering practice 
from sklearn.base import BaseEstimator, TransformerMixin
class featureAdder(BaseEstimator, TransformerMixin):
    def __init__(self,drop_feature=None):
        self.drop_feature=drop_feature
        
    def fit(self,x,y=None):
        return self

        
    def transform(self,x):
        x_new=x.copy()
        x_new["TotalFlrSF"]=x_new["1stFlrSF"]+x_new["2ndFlrSF"]
        x_new["BsmtFinSFT"]=x_new['BsmtFinSF2']+x_new['BsmtFinSF1']
        x_new['age']=x_new['YrSold']+x_new['YearBuilt']
        if self.drop_feature :
            x_new.drop(self.drop_feature,axis=1,inplace=True)
        return x_new

# %%
num_preprocessing=Pipeline([
                           ('num_imputing',SimpleImputer(strategy='mean')),
                            ('scaling_num',StandardScaler()),
                              ])
cat_preprocessing=Pipeline([('cat_imputing',SimpleImputer(strategy='most_frequent')),
                          ('ohe_cat',OneHotEncoder(handle_unknown='ignore'))])

# %%
num_preprocessing
# Out:
# Pipeline(steps=[('num_imputing', SimpleImputer()),
#                 ('scaling_num', StandardScaler())])

# %%
cat_preprocessing
# Out:
# Pipeline(steps=[('cat_imputing', SimpleImputer(strategy='most_frequent')),
#                 ('ohe_cat', OneHotEncoder(handle_unknown='ignore'))])

# %%
cat_attributes=list(X_train.select_dtypes(include="object").columns)

# %%
prepared_feat=ColumnTransformer([
                                ('num_attr',num_preprocessing,num_attributes),
                                    ('cat_attr',cat_preprocessing,cat_attributes)
                                  ])

# %%
model_pipe=Pipeline(steps=[('preprocessing',prepared_feat),                           
                           ('model',LinearRegression())])

# %%
model_pipe
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_attr',
#                                                   Pipeline(steps=[('num_imputing',
#                                                                    SimpleImputer()),
#                                                                   ('scaling_num',
#                                                                    StandardScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
# ...

# %%
model_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_attr',
#                                                   Pipeline(steps=[('num_imputing',
#                                                                    SimpleImputer()),
#                                                                   ('scaling_num',
#                                                                    StandardScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
# ...

# %%
rmse=root_mean_squared_error(y_train,model_pipe.predict(X_train))
rmse
# Out:
# 20699.68646215496

# %%
residual=y_train-model_pipe.predict(X_train)

# %%
residual.plot(kind='hist',bins=55,figsize=(10,6))# visualinzing model's residual 
plt.title('Residual of the Model')# 
plt.show()

# %%
plt.scatter(x=residual,y=model_pipe.predict(X_train))
plt.title('Residual vs Predicted Values')
plt.show()

# %%
model=model_pipe.named_steps['model']
coef=model.coef_*(model.coef_.std())
coef[:10]
# Out:
# array([ 1.88335663e+07, -9.59209253e+07,  3.94236084e+07,  3.20468029e+08,
#         3.87668201e+08,  2.81721980e+08,  4.03435746e+08,  9.02925870e+07,
#         1.32261430e+08,  3.34453781e+08])

# %%
feat_name=model_pipe.named_steps['preprocessing'].get_feature_names_out()#toimport features that-
                                                                      # used for training

# %%
coef_df=pd.DataFrame({'feat_name':feat_name,'coeficient':model.coef_}) # to features in dataframe
coef_df.sort_values(by='coeficient',ascending=False)
# Out:
#                       feat_name     coeficient
# 127  cat_attr__RoofMatl_Membran  153318.169820
# 128    cat_attr__RoofMatl_Metal  124322.999590
# 132  cat_attr__RoofMatl_WdShngl  114800.348329
# 249     cat_attr__GarageQual_Ex  101983.374211
# 101   cat_attr__Condition2_PosA   80450.612866
# ..                          ...            ...
# 233    cat_attr__Functional_Sev  -40794.561644
# 103   cat_attr__Condition2_RRAe  -63118.247056
# 254     cat_attr__GarageCond_Ex  -92731.938609
# 102   cat_attr__Condition2_PosN -193893.256820
# 125  cat_attr__RoofMatl_ClyTile -606151.590574
#
# [288 rows x 2 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
tree_pipe=Pipeline(steps=[('preprocessing',prepared_feat),#applying preprocessing
                              ('decision_tree',DecisionTreeRegressor())])#model initializing

# %%
tree_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_attr',
#                                                   Pipeline(steps=[('num_imputing',
#                                                                    SimpleImputer()),
#                                                                   ('scaling_num',
#                                                                    StandardScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
# ...

# %%
tree_rmse=root_mean_squared_error(y_train,tree_pipe.predict(X_train))
tree_rmse
# Out:
# 0.0

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
scores = cross_val_score(model_pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# Convert negative MSE scores to RMSE
rmse_scores = np.sqrt(-scores)

# Print the mean and standard deviation of RMSE
def cal_score(rmse):
    
    print("RMSE Scores:", rmse)
    print("Mean RMSE:", rmse.mean())
    print("Standard Deviation RMSE:", rmse.std())
cal_score(rmse_scores)
# Out:
# RMSE Scores: [31724.55039438 34116.50554345 38663.85690393 23844.18726949
#  49111.13997303]
# Mean RMSE: 35492.04801685743
# Standard Deviation RMSE: 8334.252848916754

# %%
scores = cross_val_score(tree_pipe, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# Convert negative MSE scores to RMSE
rmse_scores = np.sqrt(-scores)

# Print the mean and standard deviation of RMSE
def cal_score(rmse):
    
    print("RMSE Scores:", rmse)
    print("Mean RMSE:", rmse.mean())
    print("Standard Deviation RMSE:", rmse.std())
cal_score(rmse_scores)
# Out:
# RMSE Scores: [36895.04657267 36852.12233893 38823.24209752 38351.95879738
#  46943.54509824]
# Mean RMSE: 39573.18298094669
# Standard Deviation RMSE: 3767.0312771216727

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg=Pipeline(steps=[('preprocessing',prepared_feat), # first apply preprocessing 
                              ('decision_tree',RandomForestRegressor())])# model initializing
forest_reg
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_attr',
#                                                   Pipeline(steps=[('num_imputing',
#                                                                    SimpleImputer()),
#                                                                   ('scaling_num',
#                                                                    StandardScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
# ...

# %%
forest_reg.fit(X_train,y_train) # fitting data to the model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num_attr',
#                                                   Pipeline(steps=[('num_imputing',
#                                                                    SimpleImputer()),
#                                                                   ('scaling_num',
#                                                                    StandardScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
# ...

# %%
forest_rms=root_mean_squared_error(y_train,forest_reg.predict(X_train))# calculate metrice to 
                                                            #check model perfomance
forest_rms
# Out:
# 11002.932357774649

# %%
from sklearn.model_selection import cross_val_score
forest_mse_score=cross_val_score(forest_reg,X_train,y_train,scoring='neg_mean_squared_error',cv=5)#evaluating
forest_mse_score=np.sqrt(-forest_mse_score)##model performance by cross_val_score
cal_score(forest_mse_score)
# Out:
# RMSE Scores: [27010.98608382 31985.84882035 30902.72615904 24950.06218018
#  35236.49103605]
# Mean RMSE: 30017.222855889693
# Standard Deviation RMSE: 3650.039492047513

# %%
path='data//test.csv'
test_set=pd.read_csv(path)

test_pred=forest_reg.predict(test_set)
submission = pd.DataFrame({'Id': test_set['Id'], 'SalePrice': test_pred})
# Save to CSV
submission.to_csv('submission.csv', index=False)

# %%
# hyperparameter tunnning GridSeachCV
from sklearn.model_selection import GridSearchCV
#defining grid parameters for tunning
param_grid = {
    'decision_tree__n_estimators': [10, 25, 50],
    'decision_tree__max_depth': [None, 5, 10, 15],
    'decision_tree__min_samples_split': [2, 5],
    'decision_tree__min_samples_leaf': [1, 2],
    'decision_tree__max_features': ['sqrt', 'log2'],  # Fixed 'auto'
    'decision_tree__bootstrap': [True, False]
}
# Create GridSearchCV object and fit it to the data
grid_search = GridSearchCV(estimator=forest_reg, param_grid=param_grid, cv=5, 
                           n_jobs=-1, verbose=2)
# Fitting the model with GridSearchCV
grid_search.fit(X_train, y_train)
# printing out best param
print("Best parameters found: ", grid_search.best_params_)
print("Best cross-validation score: ", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Best parameters found:  {'decision_tree__bootstrap': False, 'decision_tree__max_depth': 15, 'decision_tree__max_features': 'sqrt', 'decision_tree__min_samples_leaf': 1, 'decision_tree__min_samples_split': 2, 'decision_tree__n_estimators': 25}
# Best cross-validation score:  0.8609185755773778

# %%
import joblib
joblib.dump(grid_search,"model.joblib")
# Out:
# ['model.joblib']

# %%
model=joblib.load("model.joblib")

# %%
testset=pd.read_csv("house-price-prediction/test.csv")

# %%
model_predicton=model.predict(testset)

# %%
model_predicton
# Out:
# array([123268.76621092, 150594.81222987, 177234.76946811, ...,
#        158319.8264851 , 126495.86835202, 207558.27528655], shape=(1459,))
